# %% [markdown]
# # Regression Analysis

# %% [markdown]
# <strong>Linear regression</strong> (maximum likelihood estimation): Line form $ax+b=y$. using least square. minimize the square-error between each point and line. The slope is the correlation between 2 varialbes times $\sigma_Y$ and all devided by $\sigma_X$. <br>
# <strong>Gradient descent:</strong> alternative to least squares. Basically, iterates to find the best line that follows the contour defined by the data. Usually used when dealing with 3D data. <br>
# <strong>R-square error measurement:</strong> How well the line fits the datas <br>
# $r=1-\frac{sum of squared errors}{sum of squared variations from mean}$ <br>
# $r \in [0,1]$, $0$ means none of the variances are captured, $1$ means all of the variances are captured.

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, 1000)) * 3

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %%
r_value ** 2

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# <strong>Polynominal Regression</strong>: <br>
# n order polynominal: $\sum_{i=0}^{i=n} a_ix^i$

# %%
# %matplotlib inline
from pylab import *
import numpy as np

# keep the same random data
np.random.seed(2)
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# numpy has a handy polyfit function we can use, to let us construct an nth-degree polynomial model of our data that minimizes squared error. Let's try it with a 4th degree polynomial:

# %%
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

# 4 degree polynominal
p4 = np.poly1d(np.polyfit(x, y, 4))


import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()


from sklearn.metrics import r2_score

r2 = r2_score(y, p4(x))

print(r2)
# Out:
# 0.82937663963

# %% [markdown]
# <strong>Multiple regression</strong>: when you have multiple dependent variables. Price of a car: style, brand, etc
